# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://catalog.utsa.edu/undergraduate/business/managementsciencestatistics/#courseinventory"
html = requests.get(url).content
soup = BeautifulSoup(html, 'html.parser')
nonBreakSpace = u'\xa0'

# %%
# pip install -U spacy
# python -m spacy download en_core_web_sm
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# %%
# Create an empty list to store the course names and descriptions
course_list = []

# Find all course blocks on the page
for course in soup.find_all('div', {'class': 'courseblock'}):
    
     # Extract the course name and description and remove whitespace
    course_name = course.find('p', {'class': 'courseblocktitle'}).get_text().strip()
    course_desc = course.find('p', {'class': 'courseblockdesc'}).get_text().strip()
    
    # Process the course name and description with spaCy's NLP pipeline
    course_name_nlp = nlp(course_name)
    course_desc_nlp = nlp(course_desc)
    
    # Add the course name and description to the list as a tuple of spaCy Doc objects
    course_list.append((course_name_nlp, course_desc_nlp))
    
    # Select the first course in the course_list and print its text, part-of-speech tag, and dependency label
    for token in course_list[0][1]:
        print(token.text, token.pos_, token.dep_)
# Out:
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# ...
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct
# Prerequisites NOUN ROOT
# : PUNCT punct
# A DET det
# grade NOUN appos
# of ADP prep
# " PUNCT punct
# C- PROPN pobj
# " PUNCT punct
# or CCONJ cc
# better ADV conj
# in ADP prep
# IS PROPN pobj
#   SPACE dep
# 1403 NUM nummod
# ( PUNCT punct
# or CCONJ cc
# IS AUX conj
#   SPACE dep
# 1413 NUM attr
# ) PUNCT punct
# and CCONJ cc
# MAT PROPN compound
#   SPACE dep
# 1053 NUM conj
# , PUNCT punct
# or CCONJ cc
# equivalents NOUN conj
# . PUNCT punct
#
#  SPACE dep
# This PRON nsubj
# is AUX ROOT
# the DET det
# first ADJ amod
# course NOUN attr
# in ADP prep
# a DET det
# sequence NOUN pobj
# of ADP prep
# three NUM nummod
# courses NOUN pobj
# designed VERB acl
# to PART aux
# introduce VERB xcomp
# basic ADJ amod
# statistical ADJ amod
# and CCONJ cc
# quantitative ADJ conj
# techniques NOUN dobj
# for ADP prep
# business NOUN pobj
# and CCONJ cc
# economics NOUN conj
# . PUNCT punct
# This DET det
# course NOUN nsubj
# examines VERB ROOT
# analytical ADJ amod
# skills NOUN dobj
# and CCONJ cc
# statistical ADJ amod
# concepts NOUN conj
# important ADJ amod
# in ADP prep
# business NOUN npadvmod
# - PUNCT punct
# oriented VERB amod
# environments NOUN pobj
# . PUNCT punct
# Various ADJ amod
# statistical ADJ amod
# techniques NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# presented VERB ROOT
# to PART aux
# assist VERB xcomp
# in ADP prep
# solving VERB pcomp
# problems NOUN dobj
# encountered VERB acl
# by ADP agent
# organizations NOUN pobj
# . PUNCT punct
# Topics NOUN nsubj
# include VERB ROOT
# , PUNCT punct
# but CCONJ cc
# are AUX auxpass
# not PART neg
# limited VERB conj
# to ADP prep
# , PUNCT punct
# descriptive ADJ amod
# statistics NOUN pobj
# , PUNCT punct
# measures NOUN conj
# of ADP prep
# central ADJ amod
# tendency NOUN pobj
# and CCONJ cc
# dispersion NOUN conj
# , PUNCT punct
# elementary ADJ amod
# probability NOUN compound
# theory NOUN conj
# , PUNCT punct
# expected VERB amod
# value NOUN conj
# , PUNCT punct
# random ADJ amod
# variables NOUN conj
# , PUNCT punct
# discrete ADJ amod
# and CCONJ cc
# continuous ADJ conj
# distributions NOUN conj
# , PUNCT punct
# sampling VERB amod
# distributions NOUN conj
# , PUNCT punct
# point NOUN nmod
# and CCONJ cc
# interval NOUN conj
# estimation NOUN conj
# , PUNCT punct
# and CCONJ cc
# hypothesis NOUN compound
# testing NOUN conj
# . PUNCT punct
# Electronic ADJ amod
# spreadsheets NOUN nsubjpass
# will AUX aux
# be AUX auxpass
# utilized VERB ROOT
# for ADP prep
# analyzing VERB pcomp
# and CCONJ cc
# interpreting NOUN conj
# data NOUN dobj
# . PUNCT punct
#
#  SPACE dep
# Generally ADV advmod
# offered VERB ROOT
# : PUNCT punct
# Fall PROPN dobj
# , PUNCT punct
# Spring PROPN npadvmod
# , PUNCT punct
# Summer PROPN appos
# . PUNCT punct
# Course NOUN compound
# Fees NOUN nsubj
# : PUNCT punct
# BISP NOUN appos
# $ SYM nmod
# 10 NUM npadvmod
# ; PUNCT punct
# BTSI PROPN ROOT
# $ SYM nmod
# 15.41 NUM npadvmod
# ; PUNCT punct
# DL01 PROPN appos
# $ SYM nmod
# 75 NUM appos
# ; PUNCT punct
# LRB1 PROPN appos
# $ SYM nmod
# 15.41 NUM npadvmod
# . PUNCT punct

# %%
print(len(course_list), "courses in the Department of Management Science and Statistics Undergraduate Catalog." )

ms_count = 0
sta_count = 0

for name, desc in course_list:
    if name.text.startswith("MS"):
        ms_count += 1
    elif name.text.startswith("STA"):
        sta_count += 1

print(ms_count, "being MS courses")
print(sta_count, "being STA courses")

python_count = 0

for name, desc in course_list:
    if "Python" in [token.text for token in desc]:
        python_count += 1

print("Only", python_count, "course mentions Python in the description, with that course being:")

python_count = 0

for name, desc in course_list:
    if "Python" in [token.text for token in desc]:
        print(name.text)
        python_count += 1

        # Stop looping after we've found three courses
        if python_count == 3:
            break
            
print("A class where Python is not taught but just mentioned to have the potential to be used similar to R.")
# Out:
# 49 courses in the Department of Management Science and Statistics Undergraduate Catalog.
# 23 being MS courses
# 26 being STA courses
# Only 1 course mentions Python in the description, with that course being:
# STA 4233.  Introduction to Programming and Data Management in R.  (3-0) 3 Credit Hours.
# A class where Python is not taught but just mentioned to have the potential to be used similar to R.
